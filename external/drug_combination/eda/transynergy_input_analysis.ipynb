# %% [markdown]
# # Preliminary data exploration to get a feeling of the preprocessed data.
#
# A weird thing is that the paper states vectors of length 2401 however the input is a flat vector of 4x2402 per drug drug, cell-line combination. This will need to investigated further, but probably re-generating the pre-processed input, but there was no time for that now.

# %%
from src import model, drug_drug, setting, my_data
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# Import necessary libraries
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Set visualization style
sns.set(style="whitegrid")

# %%
# Load the data
import pickle

x_path = "data/synergy_score/x.npy"  # Update the path if necessary
y_path = "data/synergy_score/y.pkl"  # Update the path if necessary

# Load X using numpy
x = np.load(x_path)

# Load Y using pickle
with open(y_path, "rb") as f:
    y = pickle.load(f)

# Display shapes of the data
print(f"Shape of X: {x.shape}")
print(f"Shape of Y: {y.shape}")  # Assuming y is a list or 1D array
# Out:
# Shape of X: (37104, 9608)
# Shape of Y: (37104, 1)

# %% [markdown]
# This means X.pny is 9

# %%
# print X
print("X data:")
print(x[:5])  # Print first 5 rows of X for inspection

# save the 1st row of X to a txt file
np.savetxt("data/synergy_score/x_first_row.txt", x[0], fmt='%s')
# Out:
# X data:
# [[-0.02958672  0.03147037 -0.05470248 ... -0.29651615 -0.33550662
#    0.        ]
#  [-0.02958672  0.03147037 -0.05470248 ... -0.29651615 -0.33550662
#    0.        ]
#  [-0.02958672  0.03147037 -0.05470248 ... -0.29651615 -0.33550662
#    0.        ]
#  [-0.02958672  0.03147037 -0.05470248 ... -0.29651615 -0.33550662
#    0.        ]
#  [-0.02958672  0.03147037 -0.05470248 ... -0.29651615 -0.33550662
#    0.        ]]

# %%
# synergy score classic 
import pandas as pd
classic_synergy_score = pd.read_csv("data/synergy_score/synergy_score.csv")
classic_synergy_score.head()
# Out:
#    Unnamed: 0 drug_a_name drug_b_name cell_line    synergy  fold  cl_fold  \
# 0           0        5-FU     ABT-888     A2058   7.693530   2.0        2
# 1           1        5-FU     AZD1775     A2058  13.052687   1.0        0
# 2           2        5-FU     BEZ-235     A2058  13.679112   1.0        4
# 3           3        5-FU  BORTEZOMIB     A2058  -5.239878   2.0        2
# 4           4        5-FU   DASATINIB     A2058  31.125644   1.0        3
#
#    drug_fold  new_drug_fold  random_fold  cluster
# 0        1.0            1.0          4.0        0
# 1        1.0            0.0          1.0        0
# 2        1.0            1.0          1.0        0
# 3        1.0            0.0          2.0        0
# 4        1.0            1.0          2.0        0

# %% [markdown]
# ## Let's examine the folds!

# %%
# we have the following fold names: fold	cl_fold	drug_fold	new_drug_fold	random_fold
fold_names = ["fold", "cl_fold", "drug_fold", "new_drug_fold", "random_fold"]

# %%
# see what drugs are in what fold!
fold_values_per_fold_name = {}
for fold_name in fold_names:
    # get number of folds in each fold
    fold = classic_synergy_score[fold_name].unique()
    fold_values_per_fold_name[fold_name] = fold
    print(f"Number of folds in {fold_name}: {len(fold)}")
    print(f"Folds in {fold_name}: {fold}")
# Out:
# Number of folds in fold: 6
# Folds in fold: [ 2.  1.  0.  3.  4. nan]
# Number of folds in cl_fold: 5
# Folds in cl_fold: [2 0 4 3 1]
# Number of folds in drug_fold: 5
# Folds in drug_fold: [1. 4. 2. 3. 0.]
# Number of folds in new_drug_fold: 2
# Folds in new_drug_fold: [1. 0.]
# Number of folds in random_fold: 5
# Folds in random_fold: [4. 1. 2. 3. 0.]

# %%
# see what drugs are in what fold!
fold_name = "new_drug_fold"
for fold_name in fold_names:

    for fold_value in fold_values_per_fold_name[fold_name]:
        # drug a names in the fold
        mask_fold= classic_synergy_score[fold_name] == fold_value
        drug_a_fold = classic_synergy_score[mask_fold]["drug_a_name"].unique()
        drug_b_fold = classic_synergy_score[mask_fold]["drug_b_name"].unique()
        # unique drugs in the fold
        drugs_unique = set(list(drug_a_fold) + list(drug_b_fold))
        print(f"Number of drugs in {fold_name} {fold_value}: {drugs_unique}")
        print(f"Numbers of drugs in {fold_name} {fold_value}: {len(drugs_unique)}")
    print("----------------------")
# Out:
# Number of drugs in fold 2.0: {'GELDANAMYCIN', 'ZOLINZA', 'CYCLOPHOSPHAMIDE', 'GEMCITABINE', 'VINBLASTINE', 'MK-2206', 'MK-8776', 'METHOTREXATE', 'MITOMYCINE', 'AZD1775', 'DASATINIB', 'MK-4541', 'MK-5108', 'PD325901', 'ABT-888', 'DEXAMETHASONE', 'SN-38', 'SUNITINIB', 'CARBOPLATIN', 'DINACICLIB', 'BORTEZOMIB', 'ETOPOSIDE', 'VINORELBINE', 'TOPOTECAN', 'PACLITAXEL', 'DOXORUBICIN', 'METFORMIN', 'LAPATINIB', 'MRK-003', '5-FU', 'MK-4827', 'BEZ-235', 'MK-8669', 'L778123', 'SORAFENIB', 'ERLOTINIB'}
# Numbers of drugs in fold 2.0: 36
# Number of drugs in fold 1.0: {'GELDANAMYCIN', 'ZOLINZA', 'CYCLOPHOSPHAMIDE', 'GEMCITABINE', 'VINBLASTINE', 'MK-2206', 'MK-8776', 'METHOTREXATE', 'MITOMYCINE', 'AZD1775', 'DASATINIB', 'MK-4541', 'MK-5108', 'PD325901', 'ABT-888', 'DEXAMETHASONE', 'SUNITINIB', 'SN-38', 'CARBOPLATIN', 'DINACICLIB', 'BORTEZOMIB', 'ETOPOSIDE', 'VINORELBINE', 'TOPOTECAN', 'PACLITAXEL', 'DOXORUBICIN', 'METFORMIN', 'LAPATINIB', 'MRK-003', '5-FU', 'MK-4827', 'BEZ-235', 'MK-8669', 'L778123', 'SORAFENIB', 'ERLOTINIB'}
# Numbers of drugs in fold 1.0: 36
# Number of drugs in fold 0.0: {'GELDANAMYCIN', 'ZOLINZA', 'CYCLOPHOSPHAMIDE', 'GEMCITABINE', 'VINBLASTINE', 'MK-2206', 'MK-8776', 'METHOTREXATE', 'MITOMYCINE', 'AZD1775', 'DASATINIB', 'MK-4541', 'MK-5108', 'PD325901', 'ABT-888', 'DEXAMETHASONE', 'SN-38', 'SUNITINIB', 'CARBOPLATIN', 'DINACICLIB', 'BORTEZOMIB', 'ETOPOSIDE', 'VINORELBINE', 'TOPOTECAN', 'PACLITAXEL', 'DOXORUBICIN', 'METFORMIN', 'LAPATINIB', 'MRK-003', '5-FU', 'MK-4827', 'BEZ-235', 'MK-8669', 'L778123', 'SORAFENIB', 'ERLOTINIB'}
# Numbers of drugs in fold 0.0: 36
# Number of drugs in fold 3.0: {'GELDANAMYCIN', 'ZOLINZA', 'CYCLOPHOSPHAMIDE', 'GEMCITABINE', 'VINBLASTINE', 'MK-2206', 'MK-8776', 'METHOTREXATE', 'MITOMYCINE', 'AZD1775', 'DASATINIB', 'MK-4541', 'MK-5108', 'PD325901', 'ABT-888', 'DEXAMETHASONE', 'SUNITINIB', 'SN-38', 'CARBOPLATIN', 'DINACICLIB', 'BORTEZOMIB', 'ETOPOSIDE', 'VINORELBINE', 'TOPOTECAN', 'PACLITAXEL', 'DOXORUBICIN', 'METFORMIN', 'LAPATINIB', 'MRK-003', '5-FU', 'MK-4827', 'MK-8669', 'BEZ-235', 'L778123', 'SORAFENIB', 'ERLOTINIB'}
# Numbers of drugs in fold 3.0: 36
# Number of drugs in fold 4.0: {'GELDANAMYCIN', 'ZOLINZA', 'CYCLOPHOSPHAMIDE', 'GEMCITABINE', 'VINBLASTINE', 'MK-2206', 'MK-8776', 'METHOTREXATE', 'MITOMYCINE', 'AZD1775', 'DASATINIB', 'MK-4541', 'PD325901', 'MK-5108', 'ABT-888', 'DEXAMETHASONE', 'SUNITINIB', 'SN-38', 'CARBOPLATIN', 'DINACICLIB', 'BORTEZOMIB', 'ETOPOSIDE', 'VINORELBINE', 'TOPOTECAN', 'PACLITAXEL', 'DOXORUBICIN', 'METFORMIN', 'LAPATINIB', 'MRK-003', '5-FU', 'MK-4827', 'BEZ-235', 'MK-8669', 'L778123', 'SORAFENIB', 'ERLOTINIB'}
# Numbers of drugs in fold 4.0: 36
# Number of drugs in fold nan: set()
# Numbers of drugs in fold nan: 0
# ----------------------
# Number of drugs in cl_fold 2: {'GELDANAMYCIN', 'ZOLINZA', 'CYCLOPHOSPHAMIDE', 'GEMCITABINE', 'VINBLASTINE', 'MK-2206', 'MK-8776', 'METHOTREXATE', 'MITOMYCINE', 'AZD1775', 'DASATINIB', 'MK-4541', 'MK-5108', 'PD325901', 'ABT-888', 'DEXAMETHASONE', 'SN-38', 'SUNITINIB', 'CARBOPLATIN', 'DINACICLIB', 'BORTEZOMIB', 'ETOPOSIDE', 'VINORELBINE', 'TOPOTECAN', 'PACLITAXEL', 'DOXORUBICIN', 'METFORMIN', 'LAPATINIB', 'MRK-003', '5-FU', 'MK-4827', 'MK-8669', 'BEZ-235', 'L778123', 'SORAFENIB', 'ERLOTINIB'}
# Numbers of drugs in cl_fold 2: 36
# Number of drugs in cl_fold 0: {'GELDANAMYCIN', 'ZOLINZA', 'CYCLOPHOSPHAMIDE', 'GEMCITABINE', 'VINBLASTINE', 'MK-2206', 'MK-8776', 'METHOTREXATE', 'MITOMYCINE', 'AZD1775', 'DASATINIB', 'MK-4541', 'MK-5108', 'PD325901', 'ABT-888', 'DEXAMETHASONE', 'SN-38', 'SUNITINIB', 'CARBOPLATIN', 'DINACICLIB', 'BORTEZOMIB', 'ETOPOSIDE', 'VINORELBINE', 'TOPOTECAN', 'PACLITAXEL', 'DOXORUBICIN', 'METFORMIN', 'LAPATINIB', 'MRK-003', '5-FU', 'MK-4827', 'BEZ-235', 'MK-8669', 'L778123', 'SORAFENIB', 'ERLOTINIB'}
# Numbers of drugs in cl_fold 0: 36
# Number of drugs in cl_fold 4: {'GELDANAMYCIN', 'ZOLINZA', 'CYCLOPHOSPHAMIDE', 'GEMCITABINE', 'VINBLASTINE', 'MK-2206', 'MK-8776', 'METHOTREXATE', 'MITOMYCINE', 'AZD1775', 'DASATINIB', 'MK-4541', 'MK-5108', 'PD325901', 'ABT-888', 'DEXAMETHASONE', 'SUNITINIB', 'SN-38', 'CARBOPLATIN', 'DINACICLIB', 'BORTEZOMIB', 'ETOPOSIDE', 'VINORELBINE', 'TOPOTECAN', 'PACLITAXEL', 'DOXORUBICIN', 'METFORMIN', 'LAPATINIB', 'MRK-003', '5-FU', 'MK-4827', 'BEZ-235', 'MK-8669', 'L778123', 'SORAFENIB', 'ERLOTINIB'}
# Numbers of drugs in cl_fold 4: 36
# Number of drugs in cl_fold 3: {'GELDANAMYCIN', 'ZOLINZA', 'CYCLOPHOSPHAMIDE', 'GEMCITABINE', 'VINBLASTINE', 'MK-2206', 'MK-8776', 'METHOTREXATE', 'MITOMYCINE', 'AZD1775', 'DASATINIB', 'MK-4541', 'MK-5108', 'PD325901', 'ABT-888', 'DEXAMETHASONE', 'SN-38', 'SUNITINIB', 'CARBOPLATIN', 'DINACICLIB', 'BORTEZOMIB', 'ETOPOSIDE', 'VINORELBINE', 'TOPOTECAN', 'PACLITAXEL', 'DOXORUBICIN', 'METFORMIN', 'LAPATINIB', 'MRK-003', '5-FU', 'MK-4827', 'BEZ-235', 'MK-8669', 'L778123', 'SORAFENIB', 'ERLOTINIB'}
# Numbers of drugs in cl_fold 3: 36
# Number of drugs in cl_fold 1: {'GELDANAMYCIN', 'ZOLINZA', 'CYCLOPHOSPHAMIDE', 'GEMCITABINE', 'VINBLASTINE', 'MK-2206', 'MK-8776', 'METHOTREXATE', 'MITOMYCINE', 'AZD1775', 'DASATINIB', 'MK-4541', 'MK-5108', 'PD325901', 'ABT-888', 'DEXAMETHASONE', 'SN-38', 'SUNITINIB', 'CARBOPLATIN', 'DINACICLIB', 'BORTEZOMIB', 'ETOPOSIDE', 'VINORELBINE', 'TOPOTECAN', 'PACLITAXEL', 'DOXORUBICIN', 'METFORMIN', 'LAPATINIB', 'MRK-003', '5-FU', 'MK-4827', 'BEZ-235', 'MK-8669', 'L778123', 'SORAFENIB', 'ERLOTINIB'}
# Numbers of drugs in cl_fold 1: 36
# ----------------------
# Number of drugs in drug_fold 1.0: {'GELDANAMYCIN', 'ZOLINZA', 'VINBLASTINE', 'MK-2206', 'MK-8776', 'AZD1775', 'DASATINIB', 'MK-5108', 'PD325901', 'ABT-888', 'SUNITINIB', 'SN-38', 'DINACICLIB', 'BORTEZOMIB', 'TOPOTECAN', 'PACLITAXEL', 'METFORMIN', 'LAPATINIB', '5-FU', 'MK-4827', 'BEZ-235', 'MK-8669', 'L778123', 'SORAFENIB', 'ERLOTINIB'}
# Numbers of drugs in drug_fold 1.0: 25
# Number of drugs in drug_fold 4.0: {'GELDANAMYCIN', 'ZOLINZA', 'CYCLOPHOSPHAMIDE', 'GEMCITABINE', 'VINBLASTINE', 'MK-2206', 'MK-8776', 'METHOTREXATE', 'MITOMYCINE', 'AZD1775', 'DASATINIB', 'MK-5108', 'PD325901', 'ABT-888', 'DEXAMETHASONE', 'SN-38', 'SUNITINIB', 'CARBOPLATIN', 'DINACICLIB', 'BORTEZOMIB', 'ETOPOSIDE', 'VINORELBINE', 'TOPOTECAN', 'PACLITAXEL', 'DOXORUBICIN', 'METFORMIN', 'LAPATINIB', 'MRK-003', '5-FU', 'MK-4827', 'BEZ-235', 'MK-8669', 'L778123', 'SORAFENIB', 'ERLOTINIB'}
# Numbers of drugs in drug_fold 4.0: 35
# Number of drugs in drug_fold 2.0: {'GELDANAMYCIN', 'ZOLINZA', 'GEMCITABINE', 'MK-2206', 'MK-8776', 'AZD1775', 'DASATINIB', 'MK-5108', 'PD325901', 'ABT-888', 'SN-38', 'SUNITINIB', 'CARBOPLATIN', 'DINACICLIB', 'BORTEZOMIB', 'ETOPOSIDE', 'TOPOTECAN', 'LAPATINIB', 'MK-4827', 'BEZ-235', 'MK-8669', 'L778123', 'SORAFENIB', 'ERLOTINIB'}
# Numbers of drugs in drug_fold 2.0: 24
# Number of drugs in drug_fold 3.0: {'GELDANAMYCIN', 'ZOLINZA', 'CYCLOPHOSPHAMIDE', 'GEMCITABINE', 'VINBLASTINE', 'MK-2206', 'MK-8776', 'METHOTREXATE', 'MITOMYCINE', 'AZD1775', 'DASATINIB', 'MK-5108', 'MK-4541', 'PD325901', 'ABT-888', 'DEXAMETHASONE', 'SUNITINIB', 'SN-38', 'CARBOPLATIN', 'DINACICLIB', 'BORTEZOMIB', 'ETOPOSIDE', 'VINORELBINE', 'TOPOTECAN', 'PACLITAXEL', 'DOXORUBICIN', 'METFORMIN', 'LAPATINIB', 'MRK-003', '5-FU', 'MK-4827', 'MK-8669', 'BEZ-235', 'L778123', 'SORAFENIB', 'ERLOTINIB'}
# Numbers of drugs in drug_fold 3.0: 36
# Number of drugs in drug_fold 0.0: {'GELDANAMYCIN', 'ZOLINZA', 'GEMCITABINE', 'MK-2206', 'MK-8776', 'AZD1775', 'PD325901', 'DASATINIB', 'MK-5108', 'ABT-888', 'SUNITINIB', 'SN-38', 'DINACICLIB', 'BORTEZOMIB', 'ETOPOSIDE', 'VINORELBINE', 'TOPOTECAN', 'DOXORUBICIN', 'LAPATINIB', 'MK-4827', 'BEZ-235', 'MK-8669', 'L778123', 'SORAFENIB', 'ERLOTINIB'}
# Numbers of drugs in drug_fold 0.0: 25
# ----------------------
# Number of drugs in new_drug_fold 1.0: {'GELDANAMYCIN', 'ZOLINZA', 'GEMCITABINE', 'VINBLASTINE', 'MK-2206', 'MK-8776', 'METHOTREXATE', 'MITOMYCINE', 'DASATINIB', 'MK-4541', 'MK-5108', 'PD325901', 'ABT-888', 'SN-38', 'SUNITINIB', 'CARBOPLATIN', 'DINACICLIB', 'ETOPOSIDE', 'VINORELBINE', 'TOPOTECAN', 'PACLITAXEL', 'DOXORUBICIN', 'METFORMIN', 'LAPATINIB', 'MRK-003', '5-FU', 'MK-4827', 'BEZ-235', 'MK-8669', 'L778123', 'SORAFENIB', 'ERLOTINIB'}
# Numbers of drugs in new_drug_fold 1.0: 32
# Number of drugs in new_drug_fold 0.0: {'GELDANAMYCIN', 'ZOLINZA', 'CYCLOPHOSPHAMIDE', 'GEMCITABINE', 'VINBLASTINE', 'MK-2206', 'MK-8776', 'METHOTREXATE', 'MITOMYCINE', 'AZD1775', 'PD325901', 'MK-4541', 'MK-5108', 'DASATINIB', 'ABT-888', 'DEXAMETHASONE', 'SUNITINIB', 'SN-38', 'CARBOPLATIN', 'DINACICLIB', 'BORTEZOMIB', 'ETOPOSIDE', 'VINORELBINE', 'TOPOTECAN', 'PACLITAXEL', 'DOXORUBICIN', 'METFORMIN', 'LAPATINIB', 'MRK-003', '5-FU', 'MK-4827', 'BEZ-235', 'MK-8669', 'L778123', 'SORAFENIB', 'ERLOTINIB'}
# Numbers of drugs in new_drug_fold 0.0: 36
# ----------------------
# Number of drugs in random_fold 4.0: {'GELDANAMYCIN', 'ZOLINZA', 'CYCLOPHOSPHAMIDE', 'GEMCITABINE', 'VINBLASTINE', 'MK-2206', 'MK-8776', 'METHOTREXATE', 'MITOMYCINE', 'AZD1775', 'DASATINIB', 'MK-4541', 'MK-5108', 'PD325901', 'ABT-888', 'DEXAMETHASONE', 'SUNITINIB', 'SN-38', 'CARBOPLATIN', 'DINACICLIB', 'BORTEZOMIB', 'ETOPOSIDE', 'VINORELBINE', 'TOPOTECAN', 'PACLITAXEL', 'DOXORUBICIN', 'METFORMIN', 'LAPATINIB', 'MRK-003', '5-FU', 'MK-4827', 'BEZ-235', 'MK-8669', 'L778123', 'SORAFENIB', 'ERLOTINIB'}
# Numbers of drugs in random_fold 4.0: 36
# Number of drugs in random_fold 1.0: {'GELDANAMYCIN', 'ZOLINZA', 'CYCLOPHOSPHAMIDE', 'GEMCITABINE', 'VINBLASTINE', 'MK-2206', 'MK-8776', 'METHOTREXATE', 'MITOMYCINE', 'AZD1775', 'DASATINIB', 'MK-4541', 'MK-5108', 'PD325901', 'ABT-888', 'DEXAMETHASONE', 'SUNITINIB', 'SN-38', 'CARBOPLATIN', 'DINACICLIB', 'BORTEZOMIB', 'ETOPOSIDE', 'VINORELBINE', 'TOPOTECAN', 'PACLITAXEL', 'DOXORUBICIN', 'METFORMIN', 'LAPATINIB', 'MRK-003', '5-FU', 'MK-4827', 'MK-8669', 'BEZ-235', 'L778123', 'SORAFENIB', 'ERLOTINIB'}
# Numbers of drugs in random_fold 1.0: 36
# Number of drugs in random_fold 2.0: {'GELDANAMYCIN', 'ZOLINZA', 'CYCLOPHOSPHAMIDE', 'GEMCITABINE', 'VINBLASTINE', 'MK-2206', 'MK-8776', 'METHOTREXATE', 'MITOMYCINE', 'AZD1775', 'DASATINIB', 'MK-4541', 'MK-5108', 'PD325901', 'ABT-888', 'DEXAMETHASONE', 'SUNITINIB', 'SN-38', 'CARBOPLATIN', 'DINACICLIB', 'BORTEZOMIB', 'ETOPOSIDE', 'VINORELBINE', 'TOPOTECAN', 'PACLITAXEL', 'DOXORUBICIN', 'METFORMIN', 'LAPATINIB', 'MRK-003', '5-FU', 'MK-4827', 'MK-8669', 'BEZ-235', 'L778123', 'SORAFENIB', 'ERLOTINIB'}
# Numbers of drugs in random_fold 2.0: 36
# Number of drugs in random_fold 3.0: {'GELDANAMYCIN', 'ZOLINZA', 'CYCLOPHOSPHAMIDE', 'GEMCITABINE', 'VINBLASTINE', 'MK-2206', 'MK-8776', 'METHOTREXATE', 'MITOMYCINE', 'AZD1775', 'DASATINIB', 'MK-4541', 'MK-5108', 'PD325901', 'ABT-888', 'DEXAMETHASONE', 'SN-38', 'SUNITINIB', 'CARBOPLATIN', 'DINACICLIB', 'BORTEZOMIB', 'ETOPOSIDE', 'VINORELBINE', 'TOPOTECAN', 'PACLITAXEL', 'DOXORUBICIN', 'METFORMIN', 'LAPATINIB', 'MRK-003', '5-FU', 'MK-4827', 'BEZ-235', 'MK-8669', 'L778123', 'SORAFENIB', 'ERLOTINIB'}
# Numbers of drugs in random_fold 3.0: 36
# Number of drugs in random_fold 0.0: {'GELDANAMYCIN', 'ZOLINZA', 'CYCLOPHOSPHAMIDE', 'GEMCITABINE', 'VINBLASTINE', 'MK-2206', 'MK-8776', 'METHOTREXATE', 'MITOMYCINE', 'AZD1775', 'DASATINIB', 'MK-4541', 'MK-5108', 'PD325901', 'ABT-888', 'DEXAMETHASONE', 'SN-38', 'SUNITINIB', 'CARBOPLATIN', 'DINACICLIB', 'BORTEZOMIB', 'ETOPOSIDE', 'VINORELBINE', 'TOPOTECAN', 'PACLITAXEL', 'DOXORUBICIN', 'METFORMIN', 'LAPATINIB', 'MRK-003', '5-FU', 'MK-4827', 'BEZ-235', 'MK-8669', 'L778123', 'SORAFENIB', 'ERLOTINIB'}
# Numbers of drugs in random_fold 0.0: 36
# ----------------------

# %%
for fold_name in fold_names:

    for fold_value in fold_values_per_fold_name[fold_name]:
        # drug a names in the fold
        mask_fold= classic_synergy_score[fold_name] == fold_value
        cell_lines_fold = set(classic_synergy_score[mask_fold]["cell_line"])
        # unique drugs in the fold
        print(f"Number of cell_lines in {fold_name} {fold_value}: {cell_lines_fold}")
        print(f"Numbers of cell_lines in {fold_name} {fold_value}: {len(cell_lines_fold)}")
    print("----------------------")
# Out:
# Number of cell_lines in fold 2.0: {'SKMES1', 'CAOV3', 'SKMEL30', 'HT144', 'A427', 'NCIH23', 'LOVO', 'UACC62', 'NCIH1650', 'RKO', 'HCT116', 'SW620', 'UWB1289', 'NCIH520', 'MDAMB436', 'A2058', 'OV90', 'A375', 'DLD1', 'KPL1', 'SW837', 'T47D', 'OCUBM', 'OVCAR3', 'NCIH460', 'A2780', 'MSTO', 'RPMI7951', 'HT29', 'SKOV3', 'ES2', 'ZR751', 'PA1', 'VCAP', 'NCIH2122'}
# Numbers of cell_lines in fold 2.0: 35
# Number of cell_lines in fold 1.0: {'SKMES1', 'CAOV3', 'SKMEL30', 'HT144', 'A427', 'NCIH23', 'LOVO', 'UACC62', 'NCIH1650', 'RKO', 'HCT116', 'SW620', 'UWB1289', 'NCIH520', 'MDAMB436', 'A2058', 'OV90', 'A375', 'DLD1', 'KPL1', 'SW837', 'T47D', 'OCUBM', 'OVCAR3', 'NCIH460', 'A2780', 'MSTO', 'RPMI7951', 'HT29', 'SKOV3', 'ES2', 'ZR751', 'PA1', 'VCAP', 'NCIH2122'}
# Numbers of cell_lines in fold 1.0: 35
# Number of cell_lines in fold 0.0: {'SKMES1', 'CAOV3', 'SKMEL30', 'HT144', 'A427', 'NCIH23', 'LOVO', 'UACC62', 'NCIH1650', 'RKO', 'HCT116', 'SW620', 'UWB1289', 'NCIH520', 'MDAMB436', 'A2058', 'OV90', 'A375', 'DLD1', 'KPL1', 'SW837', 'T47D', 'OCUBM', 'OVCAR3', 'NCIH460', 'A2780', 'MSTO', 'RPMI7951', 'HT29', 'SKOV3', 'ES2', 'ZR751', 'PA1', 'VCAP', 'NCIH2122'}
# Numbers of cell_lines in fold 0.0: 35
# Number of cell_lines in fold 3.0: {'SKMES1', 'CAOV3', 'SKMEL30', 'HT144', 'A427', 'NCIH23', 'LOVO', 'UACC62', 'NCIH1650', 'RKO', 'HCT116', 'SW620', 'UWB1289', 'NCIH520', 'MDAMB436', 'A2058', 'OV90', 'A375', 'DLD1', 'KPL1', 'SW837', 'T47D', 'OCUBM', 'OVCAR3', 'NCIH460', 'A2780', 'MSTO', 'RPMI7951', 'HT29', 'SKOV3', 'ES2', 'ZR751', 'PA1', 'VCAP', 'NCIH2122'}
# Numbers of cell_lines in fold 3.0: 35
# Number of cell_lines in fold 4.0: {'SKMES1', 'CAOV3', 'SKMEL30', 'HT144', 'A427', 'NCIH23', 'LOVO', 'UACC62', 'NCIH1650', 'RKO', 'HCT116', 'SW620', 'UWB1289', 'NCIH520', 'MDAMB436', 'A2058', 'OV90', 'A375', 'DLD1', 'KPL1', 'SW837', 'T47D', 'OCUBM', 'OVCAR3', 'NCIH460', 'A2780', 'MSTO', 'RPMI7951', 'HT29', 'SKOV3', 'ES2', 'ZR751', 'PA1', 'VCAP', 'NCIH2122'}
# Numbers of cell_lines in fold 4.0: 35
# Number of cell_lines in fold nan: set()
# Numbers of cell_lines in fold nan: 0
# ----------------------
# Number of cell_lines in cl_fold 2: {'SKMES1', 'CAOV3', 'HT144', 'A427', 'NCIH23', 'LOVO', 'UACC62', 'NCIH1650', 'RKO', 'SW620', 'NCIH520', 'MDAMB436', 'A2058', 'OV90', 'A375', 'DLD1', 'KPL1', 'SW837', 'NCIH460', 'A2780', 'MSTO', 'RPMI7951', 'HT29', 'SKOV3', 'ES2', 'ZR751', 'VCAP', 'NCIH2122'}
# Numbers of cell_lines in cl_fold 2: 28
# Number of cell_lines in cl_fold 0: {'SKMES1', 'CAOV3', 'HT144', 'A427', 'NCIH23', 'LOVO', 'UACC62', 'NCIH1650', 'RKO', 'SW620', 'NCIH520', 'MDAMB436', 'A2058', 'OV90', 'A375', 'DLD1', 'KPL1', 'SW837', 'NCIH460', 'A2780', 'MSTO', 'RPMI7951', 'HT29', 'SKOV3', 'ES2', 'ZR751', 'VCAP', 'NCIH2122'}
# Numbers of cell_lines in cl_fold 0: 28
# Number of cell_lines in cl_fold 4: {'SKMES1', 'CAOV3', 'HT144', 'A427', 'NCIH23', 'LOVO', 'UACC62', 'NCIH1650', 'RKO', 'SW620', 'NCIH520', 'MDAMB436', 'A2058', 'OV90', 'A375', 'DLD1', 'KPL1', 'SW837', 'NCIH460', 'A2780', 'MSTO', 'RPMI7951', 'HT29', 'SKOV3', 'ES2', 'ZR751', 'VCAP', 'NCIH2122'}
# Numbers of cell_lines in cl_fold 4: 28
# Number of cell_lines in cl_fold 3: {'SKMES1', 'CAOV3', 'HT144', 'A427', 'NCIH23', 'LOVO', 'UACC62', 'NCIH1650', 'RKO', 'SW620', 'NCIH520', 'MDAMB436', 'A2058', 'OV90', 'A375', 'DLD1', 'KPL1', 'SW837', 'NCIH460', 'A2780', 'MSTO', 'RPMI7951', 'HT29', 'SKOV3', 'ES2', 'ZR751', 'VCAP', 'NCIH2122'}
# Numbers of cell_lines in cl_fold 3: 28
# Number of cell_lines in cl_fold 1: {'SKMEL30', 'T47D', 'OCUBM', 'OVCAR3', 'HCT116', 'UWB1289', 'PA1'}
# Numbers of cell_lines in cl_fold 1: 7
# ----------------------
# Number of cell_lines in drug_fold 1.0: {'SKMES1', 'CAOV3', 'SKMEL30', 'HT144', 'A427', 'NCIH23', 'LOVO', 'UACC62', 'NCIH1650', 'RKO', 'HCT116', 'SW620', 'UWB1289', 'NCIH520', 'MDAMB436', 'A2058', 'OV90', 'A375', 'DLD1', 'KPL1', 'SW837', 'T47D', 'OCUBM', 'OVCAR3', 'NCIH460', 'A2780', 'MSTO', 'RPMI7951', 'HT29', 'SKOV3', 'ES2', 'ZR751', 'PA1', 'VCAP', 'NCIH2122'}
# Numbers of cell_lines in drug_fold 1.0: 35
# Number of cell_lines in drug_fold 4.0: {'SKMES1', 'CAOV3', 'SKMEL30', 'HT144', 'A427', 'NCIH23', 'LOVO', 'UACC62', 'NCIH1650', 'RKO', 'HCT116', 'SW620', 'UWB1289', 'NCIH520', 'MDAMB436', 'A2058', 'OV90', 'A375', 'DLD1', 'KPL1', 'SW837', 'T47D', 'OCUBM', 'OVCAR3', 'NCIH460', 'A2780', 'MSTO', 'RPMI7951', 'HT29', 'SKOV3', 'ES2', 'ZR751', 'PA1', 'VCAP', 'NCIH2122'}
# Numbers of cell_lines in drug_fold 4.0: 35
# Number of cell_lines in drug_fold 2.0: {'SKMES1', 'CAOV3', 'SKMEL30', 'HT144', 'A427', 'NCIH23', 'LOVO', 'UACC62', 'NCIH1650', 'RKO', 'HCT116', 'SW620', 'UWB1289', 'NCIH520', 'MDAMB436', 'A2058', 'OV90', 'A375', 'DLD1', 'KPL1', 'SW837', 'T47D', 'OCUBM', 'OVCAR3', 'NCIH460', 'A2780', 'MSTO', 'RPMI7951', 'HT29', 'SKOV3', 'ES2', 'ZR751', 'PA1', 'VCAP', 'NCIH2122'}
# Numbers of cell_lines in drug_fold 2.0: 35
# Number of cell_lines in drug_fold 3.0: {'SKMES1', 'CAOV3', 'SKMEL30', 'HT144', 'A427', 'NCIH23', 'LOVO', 'UACC62', 'NCIH1650', 'RKO', 'HCT116', 'SW620', 'UWB1289', 'NCIH520', 'MDAMB436', 'A2058', 'OV90', 'A375', 'DLD1', 'KPL1', 'SW837', 'T47D', 'OCUBM', 'OVCAR3', 'NCIH460', 'A2780', 'MSTO', 'RPMI7951', 'HT29', 'SKOV3', 'ES2', 'ZR751', 'PA1', 'VCAP', 'NCIH2122'}
# Numbers of cell_lines in drug_fold 3.0: 35
# Number of cell_lines in drug_fold 0.0: {'SKMES1', 'CAOV3', 'SKMEL30', 'HT144', 'A427', 'NCIH23', 'LOVO', 'UACC62', 'NCIH1650', 'RKO', 'HCT116', 'SW620', 'UWB1289', 'NCIH520', 'MDAMB436', 'A2058', 'OV90', 'A375', 'DLD1', 'KPL1', 'SW837', 'T47D', 'OCUBM', 'OVCAR3', 'NCIH460', 'A2780', 'MSTO', 'RPMI7951', 'HT29', 'SKOV3', 'ES2', 'ZR751', 'PA1', 'VCAP', 'NCIH2122'}
# Numbers of cell_lines in drug_fold 0.0: 35
# ----------------------
# Number of cell_lines in new_drug_fold 1.0: {'SKMES1', 'CAOV3', 'SKMEL30', 'HT144', 'A427', 'NCIH23', 'LOVO', 'UACC62', 'NCIH1650', 'RKO', 'HCT116', 'SW620', 'UWB1289', 'NCIH520', 'MDAMB436', 'A2058', 'OV90', 'A375', 'DLD1', 'KPL1', 'SW837', 'T47D', 'OCUBM', 'OVCAR3', 'NCIH460', 'A2780', 'MSTO', 'RPMI7951', 'HT29', 'SKOV3', 'ES2', 'ZR751', 'PA1', 'VCAP', 'NCIH2122'}
# Numbers of cell_lines in new_drug_fold 1.0: 35
# Number of cell_lines in new_drug_fold 0.0: {'SKMES1', 'CAOV3', 'SKMEL30', 'HT144', 'A427', 'NCIH23', 'LOVO', 'UACC62', 'NCIH1650', 'RKO', 'HCT116', 'SW620', 'UWB1289', 'NCIH520', 'MDAMB436', 'A2058', 'OV90', 'A375', 'DLD1', 'KPL1', 'SW837', 'T47D', 'OCUBM', 'OVCAR3', 'NCIH460', 'A2780', 'MSTO', 'RPMI7951', 'HT29', 'SKOV3', 'ES2', 'ZR751', 'PA1', 'VCAP', 'NCIH2122'}
# Numbers of cell_lines in new_drug_fold 0.0: 35
# ----------------------
# Number of cell_lines in random_fold 4.0: {'SKMES1', 'CAOV3', 'SKMEL30', 'HT144', 'A427', 'NCIH23', 'LOVO', 'UACC62', 'NCIH1650', 'RKO', 'HCT116', 'SW620', 'UWB1289', 'NCIH520', 'MDAMB436', 'A2058', 'OV90', 'A375', 'DLD1', 'KPL1', 'SW837', 'T47D', 'OCUBM', 'OVCAR3', 'NCIH460', 'A2780', 'MSTO', 'RPMI7951', 'HT29', 'SKOV3', 'ES2', 'ZR751', 'PA1', 'VCAP', 'NCIH2122'}
# Numbers of cell_lines in random_fold 4.0: 35
# Number of cell_lines in random_fold 1.0: {'SKMES1', 'CAOV3', 'SKMEL30', 'HT144', 'A427', 'NCIH23', 'LOVO', 'UACC62', 'NCIH1650', 'RKO', 'HCT116', 'SW620', 'UWB1289', 'NCIH520', 'MDAMB436', 'A2058', 'OV90', 'A375', 'DLD1', 'KPL1', 'SW837', 'T47D', 'OCUBM', 'OVCAR3', 'NCIH460', 'A2780', 'MSTO', 'RPMI7951', 'HT29', 'SKOV3', 'ES2', 'ZR751', 'PA1', 'VCAP', 'NCIH2122'}
# Numbers of cell_lines in random_fold 1.0: 35
# Number of cell_lines in random_fold 2.0: {'SKMES1', 'CAOV3', 'SKMEL30', 'HT144', 'A427', 'NCIH23', 'LOVO', 'UACC62', 'NCIH1650', 'RKO', 'HCT116', 'SW620', 'UWB1289', 'NCIH520', 'MDAMB436', 'A2058', 'OV90', 'A375', 'DLD1', 'KPL1', 'SW837', 'T47D', 'OCUBM', 'OVCAR3', 'NCIH460', 'A2780', 'MSTO', 'RPMI7951', 'HT29', 'SKOV3', 'ES2', 'ZR751', 'PA1', 'VCAP', 'NCIH2122'}
# Numbers of cell_lines in random_fold 2.0: 35
# Number of cell_lines in random_fold 3.0: {'SKMES1', 'CAOV3', 'SKMEL30', 'HT144', 'A427', 'NCIH23', 'LOVO', 'UACC62', 'NCIH1650', 'RKO', 'HCT116', 'SW620', 'UWB1289', 'NCIH520', 'MDAMB436', 'A2058', 'OV90', 'A375', 'DLD1', 'KPL1', 'SW837', 'T47D', 'OCUBM', 'OVCAR3', 'NCIH460', 'A2780', 'MSTO', 'RPMI7951', 'HT29', 'SKOV3', 'ES2', 'ZR751', 'PA1', 'VCAP', 'NCIH2122'}
# Numbers of cell_lines in random_fold 3.0: 35
# Number of cell_lines in random_fold 0.0: {'SKMES1', 'CAOV3', 'SKMEL30', 'HT144', 'A427', 'NCIH23', 'LOVO', 'UACC62', 'NCIH1650', 'RKO', 'HCT116', 'SW620', 'UWB1289', 'NCIH520', 'MDAMB436', 'A2058', 'OV90', 'A375', 'DLD1', 'KPL1', 'SW837', 'T47D', 'OCUBM', 'OVCAR3', 'NCIH460', 'A2780', 'MSTO', 'RPMI7951', 'HT29', 'SKOV3', 'ES2', 'ZR751', 'PA1', 'VCAP', 'NCIH2122'}
# Numbers of cell_lines in random_fold 0.0: 35
# ----------------------

# %%
# combinations_per_fold[('cl_fold', 3)]

# %%
# Initialize an empty dictionary to track (drug_a, drug_b, cell_line) combinations across folds
combinations_per_fold = {}

# Iterate over each fold
for fold_name in fold_names:
    for fold_value in fold_values_per_fold_name[fold_name]:
        mask_fold = classic_synergy_score[fold_name] == fold_value
        fold_data = classic_synergy_score[mask_fold]
        combinations_unique = set()
        for index, row in fold_data.iterrows():
            drug_a = row['drug_a_name']
            drug_b = row['drug_b_name']
            cell_line = row['cell_line']
            
            combinations_unique.add(tuple(sorted([drug_a, drug_b]) + [cell_line]))
        combinations_per_fold[(fold_name, fold_value)] = combinations_unique

# Now check for any (drug_a, drug_b, cell_line) combination that appears in multiple folds
for (fold_name_1, fold_value_1), combinations_1 in combinations_per_fold.items():
    for (fold_name_2, fold_value_2), combinations_2 in combinations_per_fold.items():
        if (fold_name_1 == fold_name_2) and (fold_value_1 != fold_value_2):  # skip comparing the same fold
            common_combinations = combinations_1.intersection(combinations_2)
            if common_combinations:
                print(f"Found common drug and cell line combinations in different folds:")
                print(f"Fold {int(fold_value_1)}: {fold_name_1}")
                print(f"Fold {int(fold_value_2)}: {fold_name_2}")
                print(f"Common combinations: ({len(common_combinations)}) {common_combinations}")
                print("----------------------")
# Out:
# Found common drug and cell line combinations in different folds:
# Fold 2: fold
# Fold 1: fold
# Common combinations: (35) {('BEZ-235', 'MK-8776', 'NCIH1650'), ('BEZ-235', 'MK-8776', 'SW837'), ('BEZ-235', 'MK-8776', 'NCIH460'), ('BEZ-235', 'MK-8776', 'UWB1289'), ('BEZ-235', 'MK-8776', 'SW620'), ('BEZ-235', 'MK-8776', 'LOVO'), ('BEZ-235', 'MK-8776', 'HCT116'), ('BEZ-235', 'MK-8776', 'MDAMB436'), ('BEZ-235', 'MK-8776', 'VCAP'), ('BEZ-235', 'MK-8776', 'ES2'), ('BEZ-235', 'MK-8776', 'OV90'), ('BEZ-235', 'MK-8776', 'OVCAR3'), ('BEZ-235', 'MK-8776', 'HT144'), ('BEZ-235', 'MK-8776', 'HT29'), ('BEZ-235', 'MK-8776', 'KPL1'), ('BEZ-235', 'MK-8776', 'NCIH2122'), ('BEZ-235', 'MK-8776', 'SKOV3'), ('BEZ-235', 'MK-8776', 'A2058'), ('BEZ-235', 'MK-8776', 'SKMES1'), ('BEZ-235', 'MK-8776', 'RPMI7951'), ('BEZ-235', 'MK-8776', 'NCIH23'), ('BEZ-235', 'MK-8776', 'ZR751'), ('BEZ-235', 'MK-8776', 'SKMEL30'), ('BEZ-235', 'MK-8776', 'MSTO'), ('BEZ-235', 'MK-8776', 'A2780'), ('BEZ-235', 'MK-8776', 'DLD1'), ('BEZ-235', 'MK-8776', 'PA1'), ('BEZ-235', 'MK-8776', 'NCIH520'), ('BEZ-235', 'MK-8776', 'RKO'), ('BEZ-235', 'MK-8776', 'A375'), ('BEZ-235', 'MK-8776', 'A427'), ('BEZ-235', 'MK-8776', 'UACC62'), ('BEZ-235', 'MK-8776', 'CAOV3'), ('BEZ-235', 'MK-8776', 'OCUBM'), ('BEZ-235', 'MK-8776', 'T47D')}
# ----------------------
# Found common drug and cell line combinations in different folds:
# Fold 1: fold
# Fold 2: fold
# Common combinations: (35) {('BEZ-235', 'MK-8776', 'NCIH1650'), ('BEZ-235', 'MK-8776', 'SW837'), ('BEZ-235', 'MK-8776', 'NCIH460'), ('BEZ-235', 'MK-8776', 'UWB1289'), ('BEZ-235', 'MK-8776', 'SW620'), ('BEZ-235', 'MK-8776', 'LOVO'), ('BEZ-235', 'MK-8776', 'HCT116'), ('BEZ-235', 'MK-8776', 'MDAMB436'), ('BEZ-235', 'MK-8776', 'VCAP'), ('BEZ-235', 'MK-8776', 'ES2'), ('BEZ-235', 'MK-8776', 'OV90'), ('BEZ-235', 'MK-8776', 'OVCAR3'), ('BEZ-235', 'MK-8776', 'HT144'), ('BEZ-235', 'MK-8776', 'HT29'), ('BEZ-235', 'MK-8776', 'KPL1'), ('BEZ-235', 'MK-8776', 'NCIH2122'), ('BEZ-235', 'MK-8776', 'SKOV3'), ('BEZ-235', 'MK-8776', 'A2058'), ('BEZ-235', 'MK-8776', 'SKMES1'), ('BEZ-235', 'MK-8776', 'RPMI7951'), ('BEZ-235', 'MK-8776', 'NCIH23'), ('BEZ-235', 'MK-8776', 'ZR751'), ('BEZ-235', 'MK-8776', 'SKMEL30'), ('BEZ-235', 'MK-8776', 'MSTO'), ('BEZ-235', 'MK-8776', 'A2780'), ('BEZ-235', 'MK-8776', 'DLD1'), ('BEZ-235', 'MK-8776', 'PA1'), ('BEZ-235', 'MK-8776', 'NCIH520'), ('BEZ-235', 'MK-8776', 'RKO'), ('BEZ-235', 'MK-8776', 'A375'), ('BEZ-235', 'MK-8776', 'A427'), ('BEZ-235', 'MK-8776', 'UACC62'), ('BEZ-235', 'MK-8776', 'CAOV3'), ('BEZ-235', 'MK-8776', 'OCUBM'), ('BEZ-235', 'MK-8776', 'T47D')}
# ----------------------
# Found common drug and cell line combinations in different folds:
# Fold 2: cl_fold
# Fold 0: cl_fold
# Common combinations: (28) {('MITOMYCINE', 'MK-8776', 'HT29'), ('LAPATINIB', 'MK-2206', 'HT29'), ('GEMCITABINE', 'MK-8776', 'CAOV3'), ('AZD1775', 'MK-8776', 'NCIH23'), ('LAPATINIB', 'MK-2206', 'NCIH2122'), ('MK-4827', 'SN-38', 'NCIH23'), ('AZD1775', 'GEMCITABINE', 'HT29'), ('AZD1775', 'DASATINIB', 'A427'), ('GEMCITABINE', 'MK-8776', 'SW620'), ('BEZ-235', 'MK-8776', 'MDAMB436'), ('MK-4827', 'MK-8776', 'A375'), ('DASATINIB', 'MK-8776', 'A375'), ('BEZ-235', 'MK-8776', 'VCAP'), ('AZD1775', 'L778123', 'HT29'), ('BEZ-235', 'MK-8776', 'SKOV3'), ('GEMCITABINE', 'MK-8776', 'ES2'), ('AZD1775', 'GEMCITABINE', 'A427'), ('LAPATINIB', 'MRK-003', 'A427'), ('GEMCITABINE', 'MK-8776', 'NCIH23'), ('AZD1775', 'DASATINIB', 'LOVO'), ('BEZ-235', 'MK-8776', 'MSTO'), ('MK-4827', 'SN-38', 'SW620'), ('AZD1775', 'GEMCITABINE', 'NCIH1650'), ('AZD1775', 'DASATINIB', 'HT29'), ('MK-2206', 'SUNITINIB', 'NCIH2122'), ('MRK-003', 'SUNITINIB', 'SW620'), ('MRK-003', 'VINBLASTINE', 'NCIH1650'), ('AZD1775', 'MK-8776', 'NCIH2122')}
# ----------------------
# Found common drug and cell line combinations in different folds:
# Fold 2: cl_fold
# Fold 4: cl_fold
# Common combinations: (25) {('L778123', 'MK-8669', 'ES2'), ('MITOMYCINE', 'MK-8776', 'ES2'), ('MRK-003', 'SUNITINIB', 'NCIH2122'), ('MK-2206', 'SUNITINIB', 'A427'), ('AZD1775', 'DASATINIB', 'A375'), ('5-FU', 'MK-8776', 'ES2'), ('ERLOTINIB', 'MK-2206', 'HT29'), ('L778123', 'MK-8669', 'A375'), ('ERLOTINIB', 'MK-2206', 'ES2'), ('MITOMYCINE', 'MK-8776', 'A427'), ('MK-2206', 'MK-8669', 'SW620'), ('BEZ-235', 'MK-8776', 'OV90'), ('MK-2206', 'MK-8669', 'LOVO'), ('DASATINIB', 'MK-8776', 'NCIH1650'), ('L778123', 'MK-8669', 'NCIH1650'), ('AZD1775', 'BEZ-235', 'ES2'), ('AZD1775', 'MK-8776', 'NCIH1650'), ('AZD1775', 'GEMCITABINE', 'A375'), ('AZD1775', 'BEZ-235', 'A2058'), ('AZD1775', 'MK-8776', 'SW620'), ('BEZ-235', 'MK-8776', 'A2780'), ('MK-4827', 'MK-8776', 'LOVO'), ('5-FU', 'MK-8776', 'CAOV3'), ('BEZ-235', 'MK-8776', 'UACC62'), ('BEZ-235', 'MK-8776', 'CAOV3')}
# ----------------------
# Found common drug and cell line combinations in different folds:
# Fold 2: cl_fold
# Fold 3: cl_fold
# Common combinations: (38) {('AZD1775', 'L778123', 'CAOV3'), ('MRK-003', 'VINBLASTINE', 'SW620'), ('BEZ-235', 'MK-8776', 'SW837'), ('MK-4827', 'SN-38', 'A2058'), ('MRK-003', 'SUNITINIB', 'ES2'), ('LAPATINIB', 'MK-2206', 'NCIH23'), ('MRK-003', 'SUNITINIB', 'NCIH23'), ('LAPATINIB', 'MRK-003', 'ES2'), ('MK-2206', 'MK-8669', 'CAOV3'), ('MK-2206', 'MK-8669', 'NCIH1650'), ('AZD1775', 'BEZ-235', 'SW620'), ('MRK-003', 'VINBLASTINE', 'HT29'), ('5-FU', 'MK-8776', 'HT29'), ('AZD1775', 'MK-8776', 'A427'), ('5-FU', 'MK-8776', 'NCIH2122'), ('MRK-003', 'VINBLASTINE', 'NCIH23'), ('BEZ-235', 'MK-8776', 'KPL1'), ('DASATINIB', 'MK-8776', 'CAOV3'), ('ERLOTINIB', 'MK-2206', 'NCIH23'), ('MK-2206', 'SUNITINIB', 'SW620'), ('BEZ-235', 'MK-8776', 'SKMES1'), ('MK-4827', 'SN-38', 'CAOV3'), ('LAPATINIB', 'MK-2206', 'NCIH1650'), ('MK-2206', 'MK-8669', 'ES2'), ('MRK-003', 'VINBLASTINE', 'A427'), ('5-FU', 'MK-8776', 'A375'), ('DASATINIB', 'MK-8776', 'LOVO'), ('MK-2206', 'MK-8669', 'NCIH23'), ('MK-2206', 'MK-8669', 'A2058'), ('MK-4827', 'SN-38', 'LOVO'), ('BEZ-235', 'MK-8776', 'NCIH520'), ('MK-2206', 'SUNITINIB', 'A2058'), ('L778123', 'MK-8669', 'LOVO'), ('MRK-003', 'VINBLASTINE', 'CAOV3'), ('MRK-003', 'SUNITINIB', 'LOVO'), ('5-FU', 'MK-8776', 'NCIH1650'), ('ERLOTINIB', 'MK-2206', 'NCIH1650'), ('MK-4827', 'MK-8776', 'ES2')}
# ----------------------
# Found common drug and cell line combinations in different folds:
# Fold 0: cl_fold
# Fold 2: cl_fold
# Common combinations: (28) {('MITOMYCINE', 'MK-8776', 'HT29'), ('LAPATINIB', 'MK-2206', 'HT29'), ('GEMCITABINE', 'MK-8776', 'CAOV3'), ('AZD1775', 'MK-8776', 'NCIH23'), ('LAPATINIB', 'MK-2206', 'NCIH2122'), ('MK-4827', 'SN-38', 'NCIH23'), ('AZD1775', 'GEMCITABINE', 'HT29'), ('AZD1775', 'DASATINIB', 'A427'), ('GEMCITABINE', 'MK-8776', 'SW620'), ('BEZ-235', 'MK-8776', 'MDAMB436'), ('MK-4827', 'MK-8776', 'A375'), ('DASATINIB', 'MK-8776', 'A375'), ('BEZ-235', 'MK-8776', 'VCAP'), ('AZD1775', 'L778123', 'HT29'), ('BEZ-235', 'MK-8776', 'SKOV3'), ('GEMCITABINE', 'MK-8776', 'ES2'), ('AZD1775', 'GEMCITABINE', 'A427'), ('LAPATINIB', 'MRK-003', 'A427'), ('GEMCITABINE', 'MK-8776', 'NCIH23'), ('AZD1775', 'DASATINIB', 'LOVO'), ('BEZ-235', 'MK-8776', 'MSTO'), ('MK-4827', 'SN-38', 'SW620'), ('AZD1775', 'GEMCITABINE', 'NCIH1650'), ('AZD1775', 'DASATINIB', 'HT29'), ('MK-2206', 'SUNITINIB', 'NCIH2122'), ('MRK-003', 'SUNITINIB', 'SW620'), ('MRK-003', 'VINBLASTINE', 'NCIH1650'), ('AZD1775', 'MK-8776', 'NCIH2122')}
# ----------------------
# Found common drug and cell line combinations in different folds:
# Fold 0: cl_fold
# Fold 4: cl_fold
# Common combinations: (36) {('L778123', 'MK-8669', 'A2058'), ('MK-4827', 'MK-8776', 'NCIH23'), ('MRK-003', 'SUNITINIB', 'HT29'), ('MK-2206', 'MK-8669', 'A375'), ('5-FU', 'MK-8776', 'SW620'), ('ERLOTINIB', 'MK-2206', 'LOVO'), ('AZD1775', 'GEMCITABINE', 'NCIH2122'), ('MRK-003', 'VINBLASTINE', 'ES2'), ('GEMCITABINE', 'MK-8776', 'LOVO'), ('AZD1775', 'MK-8776', 'A375'), ('AZD1775', 'DASATINIB', 'CAOV3'), ('MITOMYCINE', 'MK-8776', 'A375'), ('LAPATINIB', 'MK-2206', 'A375'), ('MRK-003', 'SUNITINIB', 'A375'), ('BEZ-235', 'MK-8776', 'ES2'), ('BEZ-235', 'MK-8776', 'NCIH2122'), ('BEZ-235', 'MK-8776', 'A2058'), ('L778123', 'MK-8669', 'CAOV3'), ('MK-4827', 'SN-38', 'NCIH1650'), ('LAPATINIB', 'MRK-003', 'A375'), ('MK-2206', 'SUNITINIB', 'LOVO'), ('MITOMYCINE', 'MK-8776', 'NCIH1650'), ('MRK-003', 'SUNITINIB', 'CAOV3'), ('MRK-003', 'SUNITINIB', 'NCIH1650'), ('AZD1775', 'BEZ-235', 'NCIH2122'), ('LAPATINIB', 'MRK-003', 'CAOV3'), ('MK-2206', 'SUNITINIB', 'HT29'), ('LAPATINIB', 'MK-2206', 'SW620'), ('AZD1775', 'L778123', 'A375'), ('MK-2206', 'SUNITINIB', 'NCIH23'), ('MK-4827', 'MK-8776', 'HT29'), ('LAPATINIB', 'MRK-003', 'SW620'), ('DASATINIB', 'MK-8776', 'HT29'), ('L778123', 'MK-8669', 'HT29'), ('AZD1775', 'GEMCITABINE', 'LOVO'), ('BEZ-235', 'MK-8776', 'RKO')}
# ----------------------
# Found common drug and cell line combinations in different folds:
# Fold 0: cl_fold
# Fold 3: cl_fold
# Common combinations: (24) {('LAPATINIB', 'MRK-003', 'LOVO'), ('BEZ-235', 'MK-8776', 'NCIH1650'), ('MK-4827', 'SN-38', 'NCIH2122'), ('MITOMYCINE', 'MK-8776', 'NCIH2122'), ('LAPATINIB', 'MK-2206', 'A2058'), ('AZD1775', 'BEZ-235', 'CAOV3'), ('ERLOTINIB', 'MK-2206', 'SW620'), ('MITOMYCINE', 'MK-8776', 'NCIH23'), ('AZD1775', 'L778123', 'SW620'), ('LAPATINIB', 'MRK-003', 'A2058'), ('LAPATINIB', 'MRK-003', 'NCIH2122'), ('MK-4827', 'MK-8776', 'A427'), ('5-FU', 'MK-8776', 'A2058'), ('LAPATINIB', 'MK-2206', 'A427'), ('BEZ-235', 'MK-8776', 'HT29'), ('AZD1775', 'MK-8776', 'CAOV3'), ('MK-4827', 'MK-8776', 'NCIH1650'), ('AZD1775', 'BEZ-235', 'HT29'), ('BEZ-235', 'MK-8776', 'NCIH23'), ('ERLOTINIB', 'MK-2206', 'A427'), ('BEZ-235', 'MK-8776', 'A375'), ('ERLOTINIB', 'MK-2206', 'CAOV3'), ('AZD1775', 'MK-8776', 'ES2'), ('AZD1775', 'MK-8776', 'HT29')}
# ----------------------
# Found common drug and cell line combinations in different folds:
# Fold 4: cl_fold
# Fold 2: cl_fold
# Common combinations: (25) {('L778123', 'MK-8669', 'ES2'), ('MITOMYCINE', 'MK-8776', 'ES2'), ('MRK-003', 'SUNITINIB', 'NCIH2122'), ('MK-2206', 'SUNITINIB', 'A427'), ('AZD1775', 'DASATINIB', 'A375'), ('5-FU', 'MK-8776', 'ES2'), ('ERLOTINIB', 'MK-2206', 'HT29'), ('L778123', 'MK-8669', 'A375'), ('ERLOTINIB', 'MK-2206', 'ES2'), ('MITOMYCINE', 'MK-8776', 'A427'), ('MK-2206', 'MK-8669', 'SW620'), ('BEZ-235', 'MK-8776', 'OV90'), ('MK-2206', 'MK-8669', 'LOVO'), ('DASATINIB', 'MK-8776', 'NCIH1650'), ('L778123', 'MK-8669', 'NCIH1650'), ('AZD1775', 'BEZ-235', 'ES2'), ('AZD1775', 'MK-8776', 'NCIH1650'), ('AZD1775', 'GEMCITABINE', 'A375'), ('AZD1775', 'BEZ-235', 'A2058'), ('AZD1775', 'MK-8776', 'SW620'), ('BEZ-235', 'MK-8776', 'A2780'), ('MK-4827', 'MK-8776', 'LOVO'), ('5-FU', 'MK-8776', 'CAOV3'), ('BEZ-235', 'MK-8776', 'UACC62'), ('BEZ-235', 'MK-8776', 'CAOV3')}
# ----------------------
# Found common drug and cell line combinations in different folds:
# Fold 4: cl_fold
# Fold 0: cl_fold
# Common combinations: (36) {('L778123', 'MK-8669', 'A2058'), ('MK-4827', 'MK-8776', 'NCIH23'), ('MRK-003', 'SUNITINIB', 'HT29'), ('MK-2206', 'MK-8669', 'A375'), ('5-FU', 'MK-8776', 'SW620'), ('ERLOTINIB', 'MK-2206', 'LOVO'), ('AZD1775', 'GEMCITABINE', 'NCIH2122'), ('MRK-003', 'VINBLASTINE', 'ES2'), ('GEMCITABINE', 'MK-8776', 'LOVO'), ('AZD1775', 'MK-8776', 'A375'), ('AZD1775', 'DASATINIB', 'CAOV3'), ('MITOMYCINE', 'MK-8776', 'A375'), ('LAPATINIB', 'MK-2206', 'A375'), ('MRK-003', 'SUNITINIB', 'A375'), ('BEZ-235', 'MK-8776', 'ES2'), ('BEZ-235', 'MK-8776', 'NCIH2122'), ('BEZ-235', 'MK-8776', 'A2058'), ('L778123', 'MK-8669', 'CAOV3'), ('MK-4827', 'SN-38', 'NCIH1650'), ('LAPATINIB', 'MRK-003', 'A375'), ('MK-2206', 'SUNITINIB', 'LOVO'), ('MITOMYCINE', 'MK-8776', 'NCIH1650'), ('MRK-003', 'SUNITINIB', 'CAOV3'), ('MRK-003', 'SUNITINIB', 'NCIH1650'), ('AZD1775', 'BEZ-235', 'NCIH2122'), ('LAPATINIB', 'MRK-003', 'CAOV3'), ('MK-2206', 'SUNITINIB', 'HT29'), ('LAPATINIB', 'MK-2206', 'SW620'), ('AZD1775', 'L778123', 'A375'), ('MK-2206', 'SUNITINIB', 'NCIH23'), ('MK-4827', 'MK-8776', 'HT29'), ('LAPATINIB', 'MRK-003', 'SW620'), ('DASATINIB', 'MK-8776', 'HT29'), ('L778123', 'MK-8669', 'HT29'), ('AZD1775', 'GEMCITABINE', 'LOVO'), ('BEZ-235', 'MK-8776', 'RKO')}
# ----------------------
# Found common drug and cell line combinations in different folds:
# Fold 4: cl_fold
# Fold 3: cl_fold
# Common combinations: (37) {('LAPATINIB', 'MK-2206', 'ES2'), ('AZD1775', 'MK-8776', 'A2058'), ('DASATINIB', 'MK-8776', 'NCIH23'), ('MITOMYCINE', 'MK-8776', 'A2058'), ('L778123', 'MK-8669', 'NCIH23'), ('5-FU', 'MK-8776', 'LOVO'), ('MRK-003', 'SUNITINIB', 'A2058'), ('MRK-003', 'VINBLASTINE', 'LOVO'), ('AZD1775', 'BEZ-235', 'NCIH1650'), ('AZD1775', 'GEMCITABINE', 'NCIH23'), ('AZD1775', 'L778123', 'LOVO'), ('AZD1775', 'GEMCITABINE', 'A2058'), ('MK-2206', 'SUNITINIB', 'NCIH1650'), ('DASATINIB', 'MK-8776', 'A427'), ('L778123', 'MK-8669', 'A427'), ('MRK-003', 'VINBLASTINE', 'A2058'), ('MRK-003', 'VINBLASTINE', 'NCIH2122'), ('AZD1775', 'DASATINIB', 'NCIH1650'), ('BEZ-235', 'MK-8776', 'HT144'), ('AZD1775', 'L778123', 'ES2'), ('AZD1775', 'L778123', 'NCIH2122'), ('AZD1775', 'L778123', 'A2058'), ('LAPATINIB', 'MK-2206', 'CAOV3'), ('BEZ-235', 'MK-8776', 'ZR751'), ('MK-2206', 'MK-8669', 'HT29'), ('AZD1775', 'BEZ-235', 'NCIH23'), ('DASATINIB', 'MK-8776', 'SW620'), ('5-FU', 'MK-8776', 'A427'), ('MITOMYCINE', 'MK-8776', 'SW620'), ('LAPATINIB', 'MK-2206', 'LOVO'), ('MITOMYCINE', 'MK-8776', 'LOVO'), ('GEMCITABINE', 'MK-8776', 'A375'), ('AZD1775', 'DASATINIB', 'NCIH2122'), ('AZD1775', 'DASATINIB', 'NCIH23'), ('GEMCITABINE', 'MK-8776', 'A427'), ('AZD1775', 'BEZ-235', 'A427'), ('MK-4827', 'SN-38', 'ES2')}
# ----------------------
# Found common drug and cell line combinations in different folds:
# Fold 3: cl_fold
# Fold 2: cl_fold
# Common combinations: (38) {('AZD1775', 'L778123', 'CAOV3'), ('MRK-003', 'VINBLASTINE', 'SW620'), ('BEZ-235', 'MK-8776', 'SW837'), ('MK-4827', 'SN-38', 'A2058'), ('MRK-003', 'SUNITINIB', 'ES2'), ('LAPATINIB', 'MK-2206', 'NCIH23'), ('MRK-003', 'SUNITINIB', 'NCIH23'), ('LAPATINIB', 'MRK-003', 'ES2'), ('MK-2206', 'MK-8669', 'CAOV3'), ('MK-2206', 'MK-8669', 'NCIH1650'), ('AZD1775', 'BEZ-235', 'SW620'), ('MRK-003', 'VINBLASTINE', 'HT29'), ('5-FU', 'MK-8776', 'HT29'), ('AZD1775', 'MK-8776', 'A427'), ('5-FU', 'MK-8776', 'NCIH2122'), ('MRK-003', 'VINBLASTINE', 'NCIH23'), ('BEZ-235', 'MK-8776', 'KPL1'), ('DASATINIB', 'MK-8776', 'CAOV3'), ('ERLOTINIB', 'MK-2206', 'NCIH23'), ('MK-2206', 'SUNITINIB', 'SW620'), ('BEZ-235', 'MK-8776', 'SKMES1'), ('MK-4827', 'SN-38', 'CAOV3'), ('LAPATINIB', 'MK-2206', 'NCIH1650'), ('MK-2206', 'MK-8669', 'ES2'), ('MRK-003', 'VINBLASTINE', 'A427'), ('5-FU', 'MK-8776', 'A375'), ('DASATINIB', 'MK-8776', 'LOVO'), ('MK-2206', 'MK-8669', 'NCIH23'), ('MK-2206', 'MK-8669', 'A2058'), ('MK-4827', 'SN-38', 'LOVO'), ('BEZ-235', 'MK-8776', 'NCIH520'), ('MK-2206', 'SUNITINIB', 'A2058'), ('L778123', 'MK-8669', 'LOVO'), ('MRK-003', 'VINBLASTINE', 'CAOV3'), ('MRK-003', 'SUNITINIB', 'LOVO'), ('5-FU', 'MK-8776', 'NCIH1650'), ('ERLOTINIB', 'MK-2206', 'NCIH1650'), ('MK-4827', 'MK-8776', 'ES2')}
# ----------------------
# Found common drug and cell line combinations in different folds:
# Fold 3: cl_fold
# Fold 0: cl_fold
# Common combinations: (24) {('LAPATINIB', 'MRK-003', 'LOVO'), ('BEZ-235', 'MK-8776', 'NCIH1650'), ('MK-4827', 'SN-38', 'NCIH2122'), ('MITOMYCINE', 'MK-8776', 'NCIH2122'), ('LAPATINIB', 'MK-2206', 'A2058'), ('AZD1775', 'BEZ-235', 'CAOV3'), ('ERLOTINIB', 'MK-2206', 'SW620'), ('MITOMYCINE', 'MK-8776', 'NCIH23'), ('AZD1775', 'L778123', 'SW620'), ('LAPATINIB', 'MRK-003', 'A2058'), ('LAPATINIB', 'MRK-003', 'NCIH2122'), ('MK-4827', 'MK-8776', 'A427'), ('5-FU', 'MK-8776', 'A2058'), ('LAPATINIB', 'MK-2206', 'A427'), ('BEZ-235', 'MK-8776', 'HT29'), ('AZD1775', 'MK-8776', 'CAOV3'), ('MK-4827', 'MK-8776', 'NCIH1650'), ('AZD1775', 'BEZ-235', 'HT29'), ('BEZ-235', 'MK-8776', 'NCIH23'), ('ERLOTINIB', 'MK-2206', 'A427'), ('BEZ-235', 'MK-8776', 'A375'), ('ERLOTINIB', 'MK-2206', 'CAOV3'), ('AZD1775', 'MK-8776', 'ES2'), ('AZD1775', 'MK-8776', 'HT29')}
# ----------------------
# Found common drug and cell line combinations in different folds:
# Fold 3: cl_fold
# Fold 4: cl_fold
# Common combinations: (37) {('LAPATINIB', 'MK-2206', 'ES2'), ('AZD1775', 'MK-8776', 'A2058'), ('DASATINIB', 'MK-8776', 'NCIH23'), ('MITOMYCINE', 'MK-8776', 'A2058'), ('L778123', 'MK-8669', 'NCIH23'), ('5-FU', 'MK-8776', 'LOVO'), ('MRK-003', 'SUNITINIB', 'A2058'), ('MRK-003', 'VINBLASTINE', 'LOVO'), ('AZD1775', 'BEZ-235', 'NCIH1650'), ('AZD1775', 'GEMCITABINE', 'NCIH23'), ('AZD1775', 'L778123', 'LOVO'), ('AZD1775', 'GEMCITABINE', 'A2058'), ('MK-2206', 'SUNITINIB', 'NCIH1650'), ('DASATINIB', 'MK-8776', 'A427'), ('L778123', 'MK-8669', 'A427'), ('MRK-003', 'VINBLASTINE', 'A2058'), ('MRK-003', 'VINBLASTINE', 'NCIH2122'), ('AZD1775', 'DASATINIB', 'NCIH1650'), ('BEZ-235', 'MK-8776', 'HT144'), ('AZD1775', 'L778123', 'ES2'), ('AZD1775', 'L778123', 'NCIH2122'), ('AZD1775', 'L778123', 'A2058'), ('LAPATINIB', 'MK-2206', 'CAOV3'), ('BEZ-235', 'MK-8776', 'ZR751'), ('MK-2206', 'MK-8669', 'HT29'), ('AZD1775', 'BEZ-235', 'NCIH23'), ('DASATINIB', 'MK-8776', 'SW620'), ('5-FU', 'MK-8776', 'A427'), ('MITOMYCINE', 'MK-8776', 'SW620'), ('LAPATINIB', 'MK-2206', 'LOVO'), ('MITOMYCINE', 'MK-8776', 'LOVO'), ('GEMCITABINE', 'MK-8776', 'A375'), ('AZD1775', 'DASATINIB', 'NCIH2122'), ('AZD1775', 'DASATINIB', 'NCIH23'), ('GEMCITABINE', 'MK-8776', 'A427'), ('AZD1775', 'BEZ-235', 'A427'), ('MK-4827', 'SN-38', 'ES2')}
# ----------------------

# %%
# get drug profiles 
drug_profiles = pd.read_csv("data/chemicals/random_walk_simulated_result_matrix_2401_0.3_norm_36_whole_network_no_mean")
print(drug_profiles.shape)  # Check the shape of the drug profiles data
drug_profiles.head()
fu = drug_profiles.iloc[0, 1:]
fu
# save fu to a txt file
fu.to_csv("data/synergy_score/fu.txt", index=False, header=False, sep="\t")
abt = drug_profiles.iloc[1, 1:]
abt
abt.to_csv("data/synergy_score/abt.txt", index=False, header=False, sep="\t")
# Out:
# (36, 2402)

# %%
from src.setting import data_src_dir
import os 

# gene_expression_simulated_result_matrix = os.path.join(data_src_dir, 'chemicals', 'gene_expression_simulated_result_matrix_string.csv')
random_walk_simulated_result_matrix = os.path.join(data_src_dir, 'chemicals', 'random_walk_simulated_result_matrix_2401_0.3_norm_36_whole_network_no_mean')
expressions_raw = os.path.join(data_src_dir, 'Gene_expression_raw', 'processed_expression_raw_norm')
# gene_expression_simulated_result_matrix = pd.read_csv(gene_expression_simulated_result_matrix)
gene_expression_simulated_result_matrix = pd.read_csv(expressions_raw)

# new gene dependencies
dependencies = os.path.join(data_src_dir, 'cl_gene_dp', 'new_gene_dependencies_35.csv')
cell_line_dependencies = pd.read_csv(dependencies)
print(gene_expression_simulated_result_matrix.shape)  # Check the shape of the gene expression data
gene_expression_simulated_result_matrix.head()
# Out:
# (2401, 35)
#        A427  NCIH2122      DLD1      A375     A2058   NCIH520   SKMEL30  \
# 0 -0.273078 -0.304142 -0.304142 -0.304142 -0.288151 -0.304142 -0.304142
# 1 -0.773918 -0.325653 -0.260220 -0.391230 -0.085865 -0.730296 -0.243181
# 2 -0.828568 -0.650842 -0.981242  0.444175  0.081776 -0.501425 -0.316765
# 3 -0.532818 -0.785381 -0.310439  0.276570 -0.624299  0.570205 -0.094083
# 4 -0.230535 -0.423028 -0.168958 -0.387924 -0.121237  0.109027  0.468174
#
#      NCIH23     ZR751     HT144  ...     CAOV3       PA1      T47D  RPMI7951  \
# 0 -0.227703 -0.215790 -0.271150  ... -0.304142 -0.044649 -0.304142  0.925679
# 1  0.013847  0.753229  0.277751  ... -0.710885  0.025784  0.098199  0.937678
# 2 -0.928814  0.281508  0.106493  ...  0.268718  0.755839  0.227296 -0.300564
# 3  0.285882  0.424257 -0.720020  ... -0.996985 -0.510902 -0.942987  0.737842
# 4 -0.427216  0.945924  0.290212  ...  0.303233 -0.660346 -0.303506  0.716529
#
#     NCIH460    UACC62      HT29      OV90      MSTO     A2780
# 0 -0.271386 -0.304142 -0.304142 -0.287098 -0.287693 -0.241266
# 1 -0.377994 -0.463537 -0.538839  0.722148 -0.373184 -0.706340
# 2 -0.727313 -0.910970  0.149379 -0.831689  0.931577 -0.799103
# 3  0.954848  0.148164 -0.257863  0.611112  0.542574  0.948959
# 4 -0.302386  0.459644 -0.766807  0.999213  0.362159 -0.025819
#
# [5 rows x 35 columns]

# %%
cell_line_1st = gene_expression_simulated_result_matrix['A2058']
cell_line_1st
# save cell_line_1st to a txt file
cell_line_1st.to_csv("data/synergy_score/cell_line_expressions.txt", index=False, header=False, sep="\t")

# %%
cell_line_dependencies.head()
cell_line_dependencies.shape
# Out:
# (35, 18408)

# %%
cell_line_dependencies
# Out:
#    Unnamed: 0  A1BG (1)  A1CF (29974)   A2M (2)  A2ML1 (144568)  \
# 0       A2058  0.121161      0.009714 -0.051494        0.123090
# 1       A2780  0.101243      0.063858 -0.090511        0.198627
# 2        A375  0.204070      0.188595  0.020267        0.162122
# 3        A427  0.113597      0.047437 -0.082058        0.166287
# 4       CAOV3 -0.004637      0.156147  0.155563        0.418985
# 5        DLD1  0.069601      0.093457 -0.068031        0.104992
# 6         ES2  0.102687      0.138797 -0.146108        0.227515
# 7       HT144  0.204082      0.101544 -0.043218        0.227412
# 8        HT29  0.130596      0.115155 -0.128439        0.208785
# 9        KPL1 -0.081762     -0.089361  0.036058        0.262859
# 10       LOVO  0.161831     -0.043432 -0.122189       -0.013001
# 11   MDAMB436  0.083245      0.080856 -0.097959        0.143606
# 12   NCIH1650  0.023554      0.003726 -0.059911       -0.018692
# 13   NCIH2122  0.052277      0.201560 -0.053506        0.181178
# 14     NCIH23  0.170768      0.079604  0.136060        0.186206
# 15    NCIH460  0.085778      0.123714 -0.091511        0.223305
# 16    NCIH520 -0.198717      0.149043 -0.084158        0.303386
# 17       OV90  0.113580      0.158993 -0.074518        0.157649
# 18        PA1  0.279782      0.062166  0.199500        0.462036
# 19        RKO  0.158999     -0.048684 -0.081982        0.092457
# 20   RPMI7951  0.087787      0.091397 -0.099388        0.107034
# 21    SKMEL30 -0.048090      0.350961  0.206903        0.177383
# 22     SKMES1  0.108860     -0.034579  0.147359        0.142248
# 23      SKOV3  0.050965      0.051726 -0.071419        0.093218
# 24      SW620  0.321175      0.081631 -0.149462        0.162336
# 25      SW837  0.156035      0.025139 -0.113373        0.139091
# 26     UACC62  0.146317     -0.088355 -0.096321        0.155764
# 27       VCAP -0.089135      0.270344 -0.101297        0.265895
# 28      ZR751  0.134930      0.114840  0.031288        0.246119
# 29       MSTO -0.145963     -0.183237 -0.247226        0.087296
# 30     OVCAR3 -0.459360     -0.183567  0.106796       -0.107818
# 31       T47D -0.275107     -0.055629  0.118968        0.061022
# 32      OCUBM -0.057365     -0.159785  0.292805        0.126543
# 33     HCT116 -0.089613     -0.301695  0.163122       -0.104143
# 34    UWB1289 -0.063815     -0.020721  0.172976        0.167849
#
#     A3GALT2 (127550)  A4GALT (53947)  A4GNT (51146)  AAAS (8086)  \
# 0          -0.043427       -0.033531       0.037284    -0.460394
# 1          -0.045074       -0.055184      -0.034839    -0.554135
# 2          -0.082543       -0.011568       0.232640    -0.512633
# 3          -0.015757       -0.079888      -0.136763    -0.861326
# 4          -0.096865       -0.052779      -0.009624    -0.401802
# 5          -0.118782        0.082789       0.095644    -0.725138
# 6           0.055848       -0.019664       0.067951    -0.524108
# 7          -0.477556        0.069521      -0.016153    -0.400260
# 8           0.015631        0.010579       0.272436    -0.518847
# 9          -0.134390       -0.051614      -0.040673    -0.651691
# 10         -0.163077        0.000953       0.082267    -0.316689
# 11         -0.144915       -0.104729       0.086226    -0.402451
# 12          0.030814        0.245458       0.150278    -0.717640
# 13         -0.330135       -0.001725       0.092085    -0.642735
# 14          0.070732       -0.048973       0.121084    -0.702662
# 15         -0.054302       -0.020779       0.287190    -0.640909
# 16         -0.093263       -0.053927       0.114904    -0.464050
# 17         -0.084099        0.048748       0.021902    -0.945526
# 18         -0.455156       -0.137783       0.515136    -0.513447
# 19         -0.083878        0.113311       0.092168    -0.462003
# 20         -0.109778       -0.086885       0.133200    -0.374203
# 21         -0.596030        0.480616      -0.009356    -0.367473
# 22          0.045378       -0.066079       0.226242    -0.753753
# 23         -0.045448       -0.050185       0.203814    -0.597620
# 24         -0.061053       -0.066949       0.105936    -0.505933
# 25          0.113185       -0.054416       0.117012    -0.662243
# 26         -0.020369       -0.142297       0.113166    -0.541508
# 27         -0.001831       -0.139312       0.365555     0.034022
# 28         -0.009996       -0.095928       0.203748    -0.696821
# 29          0.390905        0.038553      -0.033551    -0.509410
# 30         -0.226802        0.053495      -0.195884    -0.158395
# 31         -0.308621       -0.295516       0.170564    -0.023459
# 32         -0.265646       -0.124335       0.304994     0.065654
# 33         -0.340194       -0.089242      -0.026514    -0.128262
# 34         -0.212106       -0.287049       0.065315    -0.046843
#
#     AACS (65985)  ...  ZWILCH (55055)  ZWINT (11130)  ZXDA (7789)  \
# 0       0.035643  ...       -0.026632      -0.826179    -0.094102
# 1       0.179749  ...       -0.251870      -0.354727     0.066849
# 2       0.035820  ...       -0.274931      -0.772115    -0.138287
# 3       0.057412  ...       -0.298743      -0.591745    -0.059070
# 4       0.192245  ...       -0.354111      -0.685332    -0.194214
# 5       0.041179  ...       -0.085301      -0.733316          NaN
# 6       0.082157  ...       -0.165294      -0.541441    -0.198459
# 7      -0.114339  ...        0.132264      -0.408111    -0.225670
# 8       0.040866  ...        0.171283      -0.396706    -0.031194
# 9       0.225533  ...       -0.249396      -0.652880          NaN
# 10      0.197628  ...       -0.326736      -0.620252     0.161217
# 11      0.108514  ...       -0.035620      -0.487958    -0.034082
# 12      0.082107  ...       -0.123545      -1.010768    -0.035243
# 13      0.191715  ...       -0.305447      -0.711625    -0.100535
# 14     -0.153403  ...       -0.105207      -0.462175    -0.112709
# 15      0.174573  ...       -0.211626      -0.385762    -0.369971
# 16      0.268923  ...        0.041349      -0.843745    -0.030844
# 17     -0.016741  ...       -0.000922      -0.665789    -0.045676
# 18      0.181636  ...       -0.386202      -0.563741    -0.143376
# 19      0.087901  ...        0.020257      -0.642245     0.042897
# 20     -0.031457  ...       -0.062520      -0.543314    -0.043146
# 21      0.116311  ...       -0.244271      -0.657792    -0.353407
# 22      0.111381  ...       -0.072273      -0.748488    -0.103608
# 23      0.167085  ...        0.066904      -0.316865    -0.100685
# 24      0.137680  ...        0.112557      -0.447777     0.061963
# 25      0.068842  ...       -0.024839      -0.737449    -0.071322
# 26      0.066466  ...       -0.067322      -0.563324    -0.140713
# 27      0.187324  ...        0.022751      -0.639488    -0.442308
# 28      0.116449  ...       -0.252096      -0.704239    -0.099895
# 29      0.189129  ...       -0.237548      -0.828372     0.108768
# 30     -0.013989  ...       -0.232359      -0.342899     0.148944
# 31      0.069781  ...       -0.106436      -1.065328     0.238917
# 32      0.051156  ...       -0.116552      -0.860734     0.143922
# 33     -0.018426  ...       -0.535664      -1.101806     0.138456
# 34      0.169505  ...       -0.019535      -0.565213     0.354893
#
#     ZXDB (158586)  ZXDC (79364)  ZYG11A (440590)  ZYG11B (79699)  ZYX (7791)  \
# 0       -0.109099      0.076858         0.145727       -0.152802   -0.028473
# 1        0.008075      0.169250         0.082107       -0.203499    0.117698
# 2       -0.040445      0.197254         0.096742       -0.214836    0.084478
# 3       -0.158726      0.105864         0.054742       -0.180296    0.178126
# 4       -0.030454      0.011145         0.107885       -0.284859    0.178629
# 5             NaN      0.115573         0.043105       -0.145991    0.151187
# 6       -0.101202      0.110359         0.107340       -0.174382    0.203047
# 7       -0.018666      0.226643         0.147967       -0.298241    0.057247
# 8       -0.069612     -0.090937         0.211528       -0.041926    0.147428
# 9             NaN      0.097128         0.102997       -0.214567   -0.111066
# 10       0.286739      0.092326         0.089708       -0.224322    0.182917
# 11      -0.094170      0.108890         0.178147       -0.251019    0.201005
# 12       0.142146     -0.011656        -0.123760       -0.427789    0.062426
# 13       0.098169      0.353419        -0.064431       -0.263841    0.496060
# 14       0.136436      0.208005         0.064777       -0.272636   -0.033343
# 15      -0.146046      0.062240         0.160001       -0.087857   -0.034994
# 16      -0.132483     -0.238851         0.013895       -0.107698    0.178453
# 17      -0.034577      0.247966         0.140685       -0.181963   -0.056851
# 18       0.058935     -0.398807         1.161482        0.027894   -0.011497
# 19      -0.005386      0.101407         0.001400       -0.200267    0.073569
# 20      -0.256407      0.311677         0.087989       -0.185824    0.046778
# 21       0.202017      0.039277         0.195989       -0.324183    0.071054
# 22      -0.065179      0.063390         0.018152       -0.278229    0.189551
# 23       0.019106      0.005849         0.012877       -0.160292    0.005273
# 24       0.101535     -0.001558         0.070501       -0.179123    0.248820
# 25       0.074821      0.134915         0.094719       -0.132367    0.218211
# 26       0.041580      0.071571        -0.046072       -0.199270    0.167146
# 27       0.025144     -0.077193        -0.018239        0.037871    0.090295
# 28      -0.059366      0.119298         0.131121       -0.231961    0.084758
# 29       0.070749     -0.090800        -0.186189       -0.159288    0.169443
# 30       0.299483      0.181408        -0.187901        0.020335    0.209215
# 31       0.234984     -0.130433        -0.103030       -0.266904   -0.246655
# 32       0.203394     -0.166413         0.013861        0.038156   -0.152595
# 33       0.357755     -0.012399        -0.117841       -0.278332   -0.107725
# 34       0.238844      0.018108         0.026334       -0.197983    0.022998
#
#     ZZEF1 (23140)  ZZZ3 (26009)
# 0       -0.272026     -0.525125
# 1       -0.186366     -0.414990
# 2       -0.214730     -0.397186
# 3       -0.024363     -0.445573
# 4       -0.274277     -0.530720
# 5       -0.198643     -0.221966
# 6       -0.302491     -0.387213
# 7       -0.417931     -0.544893
# 8       -0.213733     -0.335073
# 9       -0.177253     -0.313312
# 10       0.059348     -0.253352
# 11      -0.142673     -0.240876
# 12      -0.012709     -0.424245
# 13       0.077179     -0.487537
# 14      -0.231555     -0.258785
# 15      -0.143984     -0.290764
# 16      -0.314591     -0.321310
# 17      -0.416522     -0.610892
# 18      -0.499443     -0.377913
# 19      -0.106923     -0.314879
# 20      -0.117803     -0.212552
# 21      -0.322406     -0.522764
# 22      -0.222768     -0.560274
# 23      -0.277037     -0.260870
# 24      -0.251543     -0.287559
# 25      -0.121653     -0.358849
# 26      -0.035255     -0.432660
# 27      -0.344767     -0.435740
# 28      -0.293185     -0.420751
# 29      -0.190548     -0.366854
# 30       0.190828     -0.492763
# 31       0.041183     -0.471786
# 32      -0.021150     -0.150823
# 33      -0.151682     -0.476714
# 34      -0.215609     -0.365111
#
# [35 rows x 18408 columns]
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ## Data Cleaning and Preprocessing

# %%
# Check for missing values (if applicable)
if np.isnan(x).any() or np.isnan(y).any():
    print("Missing values detected. Cleaning the data...")
    x = np.nan_to_num(x)
    y = np.nan_to_num(y)
else:
    print("No missing values detected.")
# Out:
# No missing values detected.

# %% [markdown]
# ## Basic statistics about the univariate target

# %%
# Summary statistics for Y (synergy scores)
print("Summary statistics for Y:")
print(f"Mean: {np.mean(y)}")
print(f"Median: {np.median(y)}")
print(f"Standard Deviation: {np.std(y)}")
# Out:
# Summary statistics for Y:
# Mean: 6.352110911682676
# Median: 5.0053933
# Standard Deviation: 22.223689384199524

# %% [markdown]
# ## Target variable visualisation

# %%
# Histogram of synergy scores (Y)
plt.figure(figsize=(10, 4))
sns.histplot(y, kde=True, bins=30, color="blue")
plt.title("Distribution of Synergy Scores (Y)")
plt.xlabel("Synergy Score")
plt.ylabel("Frequency")
plt.show()

# %%
unique_y, counts_y = np.unique(y, axis=0, return_counts=True)
duplicates = unique_y[counts_y > 1]
duplicate_counts = counts_y[counts_y > 1]

# Print detailed results
if len(duplicates) > 0:
    print(f"Number of duplicate synergy scores: {len(duplicates)}")
    print("Duplicate synergy scores and their counts:")
    for i, (dup, count) in list(enumerate(zip(duplicates, duplicate_counts)))[:5]:
        print(f"{i + 1}. Synergy Score: {dup}, Count: {count}")
else:
    print("No duplicate synergy scores found.")
# Out:
# Number of duplicate synergy scores: 18517
# Duplicate synergy scores and their counts:
# 1. Synergy Score: [-326.4643042], Count: 2
# 2. Synergy Score: [-307.0262696], Count: 2
# 3. Synergy Score: [-281.4366679], Count: 2
# 4. Synergy Score: [-277.8941379], Count: 2
# 5. Synergy Score: [-261.7396847], Count: 2

# %% [markdown]
# Every score is present 2 times, i.e. strong indication that this already involves permutations of drugs A and B. Using this information we can double-ckeck if our assumption about the data processing is ok.

# %%
# get indices of a random duplicated synergy score
indices = np.where(y == duplicates[0])[0]
indices
# Out:
# array([ 8450, 27002], dtype=int64)

# %%
x_dup_a, x_dup_b = x[indices[0]], x[indices[1]]
num_cols = 4
num_features = x_dup_a.shape[0] // num_cols
x_dup_a_reshaped = x_dup_a.reshape(num_cols, num_features)
x_dup_b_reshaped = x_dup_b.reshape(num_cols, num_features)

# %%
x_dup_a_reshaped
# Out:
# array([[ 4.24248739e-04,  8.37553794e-02, -6.78476579e-02, ...,
#         -1.39625932e-02, -1.03552669e-01,  3.11506738e+00],
#        [-7.30738974e-02, -9.34097213e-02, -1.00872516e-01, ...,
#         -9.30138070e-02, -1.06067235e-01,  1.79208092e+00],
#        [-7.98334966e-03, -3.65284037e-01,  3.96395710e-01, ...,
#         -1.00803422e+00,  1.93084692e-01,  0.00000000e+00],
#        [-3.04142360e-01, -3.25653404e-01, -6.50841994e-01, ...,
#         -7.49640426e-01, -3.35506618e-01,  0.00000000e+00]])

# %%
x_dup_b_reshaped
# Out:
# array([[-7.30738974e-02, -9.34097213e-02, -1.00872516e-01, ...,
#         -9.30138070e-02, -1.06067235e-01,  1.79208092e+00],
#        [ 4.24248739e-04,  8.37553794e-02, -6.78476579e-02, ...,
#         -1.39625932e-02, -1.03552669e-01,  3.11506738e+00],
#        [-7.98334966e-03, -3.65284037e-01,  3.96395710e-01, ...,
#         -1.00803422e+00,  1.93084692e-01,  0.00000000e+00],
#        [-3.04142360e-01, -3.25653404e-01, -6.50841994e-01, ...,
#         -7.49640426e-01, -3.35506618e-01,  0.00000000e+00]])

# %%
# we can clearly see that (0, :), and (1, :) of sample a and sample b are same

# %% [markdown]
# # Synergy Score Analysis
# This notebook investigates the input data from `x.npy` and `y.pkl` and generates visualizations.
#
# **Code generated with the help with GitHUb copilot in the loop**

# %% [markdown]
# "The cell line feature includes the gene expression or gene dependency of 2401 genes (when 0-indexed?). It is worth mentioning that the number of columns changes to 4 when both gene expression and dependency are used for the representation of cells. " -> Our input that is processed is of length 2402 * 4.
#
# ![image.png](attachment:image.png)

# %%
# split elements of X into segments of 4*2402 regarding drug, representing the case in the paper where 4 columns are used.

# Reshape X to have 4 columns (assuming each drug has 4 features)
feature_length = 2402  # Length of each feature vector
num_samples = x.shape[0]
num_cols = 4
x_reshaped = x.reshape(num_samples, 4, feature_length)
x_reshaped.shape  # Check the new shape
# Out:
# (37104, 4, 2402)

# %%
drugs_a = x_reshaped[:, 0, :]
drugs_b = x_reshaped[:, 1, :]
cell_line_expressions = x_reshaped[:, 2, :]
cell_line_dependencies = x_reshaped[:, 3, :]

# %%
# de-deublicate the cell line expressions and dependencies 
unique_cell_line_expressions, _ = np.unique(cell_line_expressions, axis=0, return_counts=True)
unique_cell_line_dependencies, _ = np.unique(cell_line_dependencies, axis=0, return_counts=True)

# %% [markdown]
# "We finally selected 36 drugs that targeted at least one
# protein and 35 cell lines. The final dataset has 18553 data points and 523 pairs of drug
# combinations." -- all mathes

# %%
unique_cell_line_expressions.shape
# Out:
# (35, 2402)

# %%
unique_cell_line_dependencies.shape
# Out:
# (35, 2402)

# %%
unique_cell_line_expressions, first_indices = np.unique(cell_line_expressions, axis=0, return_index=True)

# %%
first_indices
# Out:
# array([15937, 10146,  3756,  9623,  2149,  1065,  1607, 11192, 13826,
#        14872,  9100,  8016,  2691, 14349, 17506, 12257, 15414,  5363,
#            0, 16983, 10669,  3214, 16460,   542, 13303,  4821,  6951,
#         8558,  7474,  4298, 18029,  6428, 12780,  5886, 11715],
#       dtype=int64)

# %% [markdown]
# # PCA of cell lines

# %%
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# Perform PCA to reduce dimensions to 2D
pca_expressions = PCA(n_components=2)
cell_line_expressions_pca = pca_expressions.fit_transform(cell_line_expressions)

pca_dependencies = PCA(n_components=2)
cell_line_dependencies_pca = pca_dependencies.fit_transform(cell_line_dependencies)

# Create a figure with two subplots
fig, axes = plt.subplots(1, 2, figsize=(20, 5), sharey=True)

# Plot PCA for cell_line_expressions
axes[0].scatter(cell_line_expressions_pca[:, 0], cell_line_expressions_pca[:, 1], alpha=0.7, c='blue', marker='o')
axes[0].set_title("PCA of Cell Line Expressions")
axes[0].set_xlabel("Principal Component 1")
axes[0].set_ylabel("Principal Component 2")
axes[0].grid(True)

# Plot PCA for cell_line_dependencies
axes[1].scatter(cell_line_dependencies_pca[:, 0], cell_line_dependencies_pca[:, 1], alpha=0.7, c='orange', marker='x')
axes[1].set_title("PCA of Cell Line Dependencies")
axes[1].set_xlabel("Principal Component 1")
axes[1].grid(True)

# Adjust layout and show the plot
plt.tight_layout()
plt.show()

# %%
import seaborn as sns

# Assuming pca_expressions is the PCA model for expressions
pc1_weights = pca_expressions.components_[0]

# Convert weights into a 2D array for better visualization
pc1_weights = np.reshape(pc1_weights, (1, -1))  # Reshape to 1 row, 2402 columns

# Create a heatmap
plt.figure(figsize=(20, 2))  # Adjust size to make it look good
sns.heatmap(pc1_weights, cmap='viridis', cbar=True, xticklabels=False, yticklabels=False)
plt.title("Heatmap of First Principal Component (PC1) Weights")
plt.show()# Assuming pc1_weights is a 1D array of shape (2402,)
pc1_weights = pca_expressions.components_[0]

# Sort the absolute values of the weights and pick the top N
top_n = 50
sorted_indices = np.argsort(np.abs(pc1_weights))[::-1]  # Sort by absolute value, descending
top_n_indices = sorted_indices[:top_n]  # Indices of the top N features

# Plot the top N weights using the correct indices
top_n_weights = pc1_weights[top_n_indices]

# Now plot the top N weights
plt.figure(figsize=(10, 6))
plt.bar(range(top_n), top_n_weights)
plt.title(f"Top {top_n} Features for PC1 Weights")
plt.xlabel("Feature Index (Gene)")
plt.ylabel("Weight")
plt.xticks(range(top_n), top_n_indices, rotation=90)  # Show the indices on the x-axis
plt.grid(True)
plt.show()

# %% [markdown]
# ## Interestingly deduplication of drugs does not work the same ... But their PCA is the same

# %%
full_unique_drugs, _ = np.unique(drugs_a[:,:], axis=0, return_counts=True)

# %%
full_unique_drugs.shape # what is this last axis??????
# Out:
# (14696, 2402)

# %%
# de-deublicate the drugs a and b
unique_drugs, _ = np.unique(drugs_a[:,:-1], axis=0, return_counts=True)

# %%
unique_drugs.shape
# Out:
# (35, 2401)

# %%
unique_drugs.shape
# Out:
# (35, 2401)

# %%
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# Perform PCA to reduce dimensions to 2D
pca_drugs = PCA(n_components=2)
drugs_pca = pca_drugs.fit_transform(unique_drugs)

pca_full_drugs= PCA(n_components=2)
full_drugs_pca = pca_full_drugs.fit_transform(full_unique_drugs)

# Create a figure with two subplots
fig, axes = plt.subplots(1, 2, figsize=(20, 5), sharey=True)

# Plot PCA for cell_line_expressions
axes[0].scatter(drugs_pca[:, 0], drugs_pca[:, 1], alpha=0.7, c='blue', marker='o')
axes[0].set_title("PCA of Drugs")
axes[0].set_xlabel("Principal Component 1")
axes[0].set_ylabel("Principal Component 2")
axes[0].grid(True)

# Plot PCA for cell_line_dependencies
axes[1].scatter(full_drugs_pca[:, 0], full_drugs_pca[:, 1], alpha=0.7, c='orange', marker='x')
axes[1].set_title("PCA of Full Drugs")
axes[1].set_xlabel("Principal Component 1")
axes[0].set_ylabel("Principal Component 2")
axes[1].grid(True)

# Adjust layout and show the plot
plt.tight_layout()
plt.show()

# %%
import seaborn as sns

# Assuming pca_expressions is the PCA model for expressions
pc1_weights = pca_drugs.components_[0]

# Convert weights into a 2D array for better visualization
pc1_weights = np.reshape(pc1_weights, (1, -1))  # Reshape to 1 row, 2402 columns

# Create a heatmap
plt.figure(figsize=(20, 2))  # Adjust size to make it look good
sns.heatmap(pc1_weights, cmap='viridis', cbar=True, xticklabels=False, yticklabels=False)
plt.title("Heatmap of First Principal Component (PC1) Weights of Drugs")
plt.show()# Assuming pc1_weights is a 1D array of shape (2402,)
pc1_weights = pca_drugs.components_[0]

# Sort the absolute values of the weights and pick the top N
top_n = 50
sorted_indices = np.argsort(np.abs(pc1_weights))[::-1]  # Sort by absolute value, descending
top_n_indices = sorted_indices[:top_n]  # Indices of the top N features

# Plot the top N weights using the correct indices
top_n_weights = pc1_weights[top_n_indices]

# Now plot the top N weights
plt.figure(figsize=(20, 4))
plt.bar(range(top_n), top_n_weights)
plt.title(f"Top {top_n} Features for PC1 Weights (Drugs)")
plt.xlabel("Feature Index (Gene)")
plt.ylabel("Weight")
plt.xticks(range(top_n), top_n_indices, rotation=90)  # Show the indices on the x-axis
plt.grid(True)
plt.show()

# %%
# Look for duplicate samples in axis -1 in the reshaped data for example (37104, 2, :) and (37103, 2, :) could be fuplicates but the 2nd axis is always fixed!
_, counts = np.unique(x_reshaped, axis=0, return_counts=True)
counts
# Out:
# array([1, 1, 1, ..., 1, 1, 1], dtype=int64)

# %%
import seaborn as sns

# Assuming pca_expressions is the PCA model for expressions
pc1_weights = pca_full_drugs.components_[0]

# Convert weights into a 2D array for better visualization
pc1_weights = np.reshape(pc1_weights, (1, -1))  # Reshape to 1 row, 2402 columns

# Create a heatmap
plt.figure(figsize=(12, 2))  # Adjust size to make it look good
sns.heatmap(pc1_weights, cmap='viridis', cbar=True, xticklabels=False, yticklabels=False)
plt.title("Heatmap of First Principal Component (PC1) Weights of Drugs")
plt.show()# Assuming pc1_weights is a 1D array of shape (2402,)
pc1_weights = pca_full_drugs.components_[0]

# Sort the absolute values of the weights and pick the top N
top_n = 50
sorted_indices = np.argsort(np.abs(pc1_weights))[::-1]  # Sort by absolute value, descending
top_n_indices = sorted_indices[:top_n]  # Indices of the top N features

# Plot the top N weights using the correct indices
top_n_weights = pc1_weights[top_n_indices]

# Now plot the top N weights
plt.figure(figsize=(10, 6))
plt.bar(range(top_n), top_n_weights)
plt.title(f"Top {top_n} Features for PC1 Weights (Drugs)")
plt.xlabel("Feature Index (Gene)")
plt.ylabel("Weight")
plt.xticks(range(top_n), top_n_indices, rotation=90)  # Show the indices on the x-axis
plt.grid(True)
plt.show()

# %% [markdown]
# quick and dirty notebook for sure, but gets us a first feeling about the data w/o the need of re-generation of the data
